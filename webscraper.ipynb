# %%
#pip install splinter

# %%
#Import dependencies.
import pandas as pd
import json
import requests

from bs4 import BeautifulSoup as bs

import splinter
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist

import time

# %%
#MAC USERS

#Define executable path and initialize chrome browser.

#executable_path = {'executable_path':'chromedriver'}
#browser = splinter.Browser('chrome', **executable_path)

# %%
#WINDOWS USERS

#Define executable path and initialize chrome browser.

executable_path = {"executable_path":'chromedriver.exe'}
browser = Browser("chrome", **executable_path)

# %%
#Connect to website

url = 'https://connectmentors.com/mentors'
browser.visit(url)

# %%
#Define html object

html = browser.html

#Parse html using BeautifulSoup
soup = bs(html, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, viewport-fit=cover" name="viewport"/>
#   <title>
#    Connect Mentors - Home
#   </title>
#   <link href="/images/connectmentors/favicon.ico" rel="shortcut icon"/>
#   <meta content="Aerate Inc" name="author"/>
#   <meta content="Aerate Inc" name="copyright"/>
#   <meta content="Get matched with Mentors from Britains most exciting organisations." name="description"/>
#   <meta content="success, diversity, marketing, mentor, recruitment, mentee, employment, weekend jobs, employment law, driving jobs, resume, jobs in london, sports jobs, highest paying jobs, environmental jobs, market research, arts jobs, careers advice, job today, google jobs, agency work, recruitment agencies london, receptionist jobs, advertisement, human resources, reed recruitment, security jobs, teaching jobs, retail jobs, work from home, jobs uk, warehouse jobs, graduate jobs, marketing agency, nursing jobs, marketing recruitment agencies, temp agencies, sales jobs, university jobs, employee rights, jobs in canada, banking jobs, research jobs, welding jobs, social marketing, hr jobs, local part time jobs, recruitment agencies uk, paralegal jobs, entry level jobs, engineering recruitment agencies, student jobs, science jobs, summer jobs, niche market, hr recruiter, opening, network marketing, law jobs, critical success factors, job advertisement, library jobs, how to find a job, the mentor, gov job search, what is marketing, maintenance jobs, marketing companies, computer jobs, pa jobs, job design, email marketing, recruitment software, medical jobs, experiential marketing, event marketing, marketing courses, recruiting solutions, free job posting, overseas jobs, executive jobs, it recruitment agencies, healthcare jobs, telecom jobs, jobs for students, airline jobs, trainee jobs, recruiting agencies, automotive jobs, coaching and mentoring, pharmacist jobs, graduate recruitment, aviation jobs, legal recruitment, radio advertising, music jobs, travel jobs, advertising agency, job search uk, employment contract, business marketing, e marketing, jobs in australia, pharmaceutical jobs, b2b marketing, seasonal jobs, it recruitment, tv advertising, management jobs, coaching, free market, finance recruitment agencies, construction recruitment, accounting jobs, technician jobs, engineering jobs, jobs in houston, restaurant jobs, construction recruitment agencies, education jobs, executive search, construction jobs, affiliate marketing, contract jobs, temping agencies, marketing consultant, customer service jobs, human resources jobs, insurance jobs, admin jobs, direct mail, graduate recruitment agencies, finance jobs, jobs for teens, hotel jobs, mentor training, teen jobs, part time jobs for students, legal jobs, recruitment consultant jobs, social work jobs, call center jobs, internet marketing, marketing jobs, hospital jobs, hr recruitment agencies, personal agency, job career, uk jobs, cultural diversity, job description, diversity and inclusion, marketing news, job boards, brand strategy, what is a mentor, marketing communication, job fair, marketing techniques, what is diversity, marketing concept, best jobs, recruitment companies, college jobs, headhunters, manpower recruitment, sales and marketing, what is equality and diversity, list of jobs, mentor definition, postal jobs, get a job, career finder, recruitment consultant, diversity jobs, hire, new job, marketing campaign, how to get a job, times jobs, recruitment london, employ, jobs in, good job, job application, marketing strategy, marketing objectives, apply for jobs online, media jobs, it jobs, sports marketing, job search sites, job interview tips, marketing plan, best job sites, job opportunities, find jobs, job websites, online marketing, looking for a job, diversity in the workplace, job openings, job search websites, vacancy, find me a job, marketing management, jobs hiring, business jobs, career guidance, i need a job, marketer, marketing strategies, jobs in my area, target market, job hunting, career opportunities, headhunter, direct marketing, brand manager" name="keywords"/>
#   <meta content="connectmentors" name="instance"/>
#   <meta content="Connect Mentors" property="og:site_name"/>
#   <meta content="https://connect-mentors.s3.eu-west-2.amazonaws.com/shared/app.png" property="og:image"/>
#   <meta content="Connect Mentors" property="og:title"/>
#   <meta content="Get matched with Mentors from Britains most exciting organisations." property="og:description"/>
#   <meta content="https://connectmentors.com" property="og:url"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="https://connect-mentors.s3.eu-west-2.amazonaws.com/shared/app.png" name="twitter:image"/>
#   <meta content="Get matched with Mentors from Britains most exciting organisations." name="twitter:description"/>
#   <link href="/less/style.min.css?v=StvQQKTQ0HtCw0maaA83xrMWeANhINH6beoafjPVa5c" rel="stylesheet"/>
#   <link href="/less/style.tablet.min.css?v=tddpMeqnigqhPC7ah7bxLF9u7eSNDAsOCZWKelyQuEY" rel="stylesheet"/>
#   <link href="/less/style.mobile.min.css?v=gUGe2ipVutEaZ1bhLptvrv1fAKmld8HpeMVXo8_HF-8" rel="stylesheet"/>
#   <link href="/css/swiper.min.css?v=Xl4jhUj_invyLTvyjS5vAqYQc8HUpgixKC5uy7wZnDc" rel="stylesheet"/>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-105161457-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || []; function gtag() { dataLayer.push(arguments); } gtag('js', new Date()); gtag('config', 'UA-105161457-1');
#   </script>
#   <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.5.0/css/all.css" integrity="sha384-B4dIYHKNBt8Bc12p+WXckhzcICo0wtJAoU8YZTY5qE0Id1GSseTk6S+L3BlXeVIU" rel="stylesheet"/>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/select2/4.0.6-rc.0/css/select2.min.css" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Montserrat:300,400,500,600,700,800,900|PT+Serif:300,400,500,600,700,800,900" rel="stylesheet"/>
#  </head>
#  <body class="modal-open1">
#   <header>
#    <div class="container">
#     <div class="content">
#      <a class="responsive-menu-nav">
#       <div class="menu-stick">
#       </div>
#       <div class="menu-stick">
#       </div>
#       <div class="menu-stick">
#       </div>
#      </a>
#      <a class="logo" href="/">
#       <img alt="site logo" src="https://connect-mentors.s3.eu-west-2.amazonaws.com/shared/app.png"/>
#      </a>
#     </div>
#    </div>
#   </header>
#   <section class="site-container">
#    <section class="mentors-section">
#     <div class="content">
#      <div class="">
#       <h1 class="title">
#        View our Mentors
#       </h1>
#       <h2 class="sub-title">
#        Connect with a Mentor from the most progressive organisations
#       </h2>
#       <div class="mentors-section-header">
#        <div class="sort-container">
#         <label>
#          Sort by:
#         </label>
#         <select id="sort-order">
#          <option value="asc">
#           A - Z
#          </option>
#          <option value="desc">
#           Z - A
#          </option>
#         </select>
#        </div>
#        <div class="search-container">
#         <input autocomplete="off" id="mentor-search" placeholder="Search Mentors..." type="text"/>
#        </div>
#       </div>
#      </div>
#      <div class="mentor-list-container">
#       <a class="mentor-item" href="/mentors/olusina-abimbola-sanni" itemprop="url">
#        <div class="mentor-image">
#         <img alt="Olusina Abimbola Sanni" itemprop="image" src="https://connect-mentors.s3.eu-west-2.amazonaws.com/users/16187/profile.jpg?lu=637433883307526100"/>
#        </div>
#        <div class="mentor-head">
#         <h4 class="mentor-location" itemprop="location">
#          Lagos
#         </h4>
#         <h3 class="mentor-name" itemprop="name">
#          Olusina Abimbola Sanni
#         </h3>
#         <div class="mentor-position" itemprop="jobTitle">
#          Executive Partner
#         </div>
#        </div>
#        <div class="mentor-body">
#         Insurance, Sales and Retail
#        </div>
#       </a>
#       <a class="mentor-item" href="/mentors/mary-mosope-adeyemi" itemprop="url">
#        <div class="mentor-image">
#         <img alt="Mary Mosope Adeyemi" itemprop="image" src="https://connect-mentors.s3.eu-west-2.amazonaws.com/users/15936/profile.jpg?lu=636803792180000000"/>
#        </div>
#        <div class="mentor-head">
#         <h4 class="mentor-location" itemprop="location">
#          London
#         </h4>
#         <h3 class="mentor-name" itemprop="name">
#          Mary Mosope Adeyemi
#         </h3>
#         <div class="mentor-position" itemprop="jobTitle">
#          Executive Director - Credit Risk Management at Goldman Sachs
#         </div>
#        </div>
#        <div class="mentor-body">
#         Accountancy, Financial Management, Financial Servi...
#        </div>
#       </a>
#       <a class="mentor-item" href="/mentors/foluke-akinlose-mbe" itemprop="url">
#        <div class="mentor-image">
#         <img alt="Foluke Akinlose MBE" itemprop="image" src="https://connect-mentors.s3.eu-west-2.amazonaws.com/users/15571/profile.jpg?lu=636742493690000000"/>
#        </div>
#        <div class="mentor-head">
#         <h4 class="mentor-location" itemprop="location">
#          London
#         </h4>
#         <h3 class="mentor-name" itemprop="name">
#          Foluke Akinlose MBE
#         </h3>
#         <div class="mentor-position" itemprop="jobTitle">
#          Founder at PRECIOUS
#         </div>
#        </div>
#        <div class="mentor-body">
#         Journalism and Publishing, Media
#        </div>
#       </a>
#       <a class="mentor-item" href="/mentors/tunji-akintokun" itemprop="url">
#        <div class="mentor-image">
#         <img alt="Tunji Akintokun" itemprop="image" src="https://connect-mentors.s3.eu-west-2.amazonaws.com/users/15576/profile.jpg?lu=636742545230000000"/>
#        </div>
#        <div class="mentor-head">
#         <h4 class="mentor-location" itemprop="location">
#          London
#         </h4>
#         <h3 class="mentor-name" itemprop="name">
#          Tunji Akintokun
#         </h3>
#         <div class="mentor-position" itemprop="jobTitle">
#          Director at Cisco
#         </div>
#        </div>
#        <div class="mentor-body">
#         Charity and Social Work, Engineering and Manufactu...
#        </div>
#       </a>
#       <a class="mentor-item" href="/mentors/abdulaziz-ali" itemprop="url">
#        <div class="mentor-image">
#         <img alt="Abdulaziz Ali" itemprop="image" src="https://connect-mentors.s3.eu-west-2.amazonaws.com/users/16131/profile.jpg?lu=637285244736759420"/>
#        </div>
#        <div class="mentor-head">
#         <h4 class="mentor-location" itemprop="location">
#          Addis Ababa
#         </h4>
#         <h3 class="mentor-name" itemprop="name">
#          Abdulaziz Ali
#         </h3>
#         <div class="mentor-position" itemprop="jobTitle">
#          Software Engineer
#         </div>
#        </div>
#        <div class="mentor-body">
#         IT and Technology
#        </div>
#       </a>
#       <a class="mentor-item" href="/mentors/paul-asare-archer" itemprop="url">
#        <div class="mentor-image">
#         <img alt="Paul Asare-Archer" itemprop="image" src="https://connect-mentors.s3.eu-west-2.amazonaws.com/users/15932/profile.jpg?lu=636800467020000000"/>
#        </div>
#        <div class="mentor-head">
#         <h4 class="mentor-location" itemprop="location">
#          High Wycombe
#         </h4>
#         <h3 class="mentor-name" itemprop="name">
#          Paul Asare-Archer
#         </h3>
#         <div class="mentor-position" itemprop="jobTitle">
#          Director of Compliance at Telefónica
#         </div>
#        </div>
#        <div class="mentor-body">
#         Financial Management, Financial Services, Law
#        </div>
#       </a>
#       <a class="mentor-item" href="/mentors/emily-atkinson" itemprop="url">
#        <div class="mentor-image">
#         <img alt="Emily Atkinson" itemprop="image" src="https://connect-mentors.s3.eu-west-2.amazonaws.com/users/15537/profile.jpg?lu=636753842060000000"/>
#        </div>
#        <div class="mentor-head">
#         <h4 class="mentor-location" itemprop="location">
#          London
#         </h4>
#         <h3 class="mentor-name" itemprop="name">
#          Emily Atkinson
#         </h3>
#         <div class="mentor-position" itemprop="jobTitle">
#          Software Engineer at Condé Nast
#         </div>
#        </div>
#        <div class="mentor-body">
#         Engineering and Manufacturing, IT and Technology
#        </div>
#       </a>
#       <a class="mentor-item" href="/mentors/leigh-baker-7383095" itemprop="url">
#        <div class="mentor-image">
#         <img alt="Leigh Baker" itemprop="image" src="https://connect-mentors.s3.eu-west-2.amazonaws.com/users/16042/profile.jpg?lu=637084589320000000"/>
#        </div>
#        <div class="mentor-head">
#         <h4 class="mentor-location" itemprop="location">
#          York
#         </h4>
#         <h3 class="mentor-name" itemprop="name">
#          Leigh Baker
#         </h3>
#         <div class="mentor-position" itemprop="jobTitle">
#          Founder at we@leighbaker
#         </div>
#        </div>
#        <div class="mentor-body">
#         Consumer Goods and FMCG, Creative and Production, ...
#        </div>
#       </a>
#      </div>
#      <div class="loader-container" id="mentor-list-loader" style="display: block; opacity: 1;">
#       <img alt="Loading Animation" class="" src="/images/loader.gif"/>
#      </div>
#     </div>
#    </section>
#    <section class="contact-us-section">
#     <div class="container">
#      <h2 class="title">
#       Become a Mentor
#      </h2>
#      <h3 class="sub-title">
#       If you are interested in knowing more about becoming a Mentor, register your interest below
#      </h3>
#      <div class="contact-us-form">
#       <form id="contact-us-form" novalidate="novalidate">
#        <input class="contact-form-field" id="contact-mode" type="hidden" value="mentor"/>
#        <div class="form-group">
#         <input class="contact-form-field" id="contact-forename" name="contact_forename" placeholder="First Name" required="" type="text"/>
#        </div>
#        <div class="form-group">
#         <input class="contact-form-field" id="contact-surname" name="contact_surname" placeholder="Last Name" required="" type="text"/>
#        </div>
#        <div class="form-group">
#         <input class="contact-form-field" id="contact-email" name="contact_email" placeholder="Email" required="" type="email"/>
#        </div>
#        <div class="form-group">
#         <textarea class="contact-form-field" id="contact-message" name="contact_message" placeholder="Message" required=""></textarea>
#        </div>
#        <button class="btn-contact-us-submit" style="cursor:pointer" type="button">
#         Submit
#        </button>
#       </form>
#      </div>
#     </div>
#    </section>
#   </section>
#   <footer>
#    <div class="nav-section">
#     <div class="content">
#      <ul class="footer-nav-menu">
#       <li>
#        <a href="/about">
#         About
#        </a>
#       </li>
#       <li>
#        <a href="/howitworks">
#         How it works
#        </a>
#       </li>
#       <li class='"active"'>
#        <a href="/mentors">
#         Mentors
#        </a>
#       </li>
#       <li>
#        <a href="/companies">
#         Companies
#        </a>
#       </li>
#       <li>
#        <a href="/partners">
#         Partners
#        </a>
#       </li>
#       <li>
#        <a href="/skills">
#         Skills
#        </a>
#       </li>
#       <li>
#        <a class="btn-login btn-login-show" href="javascript:void(0)">
#         Log in
#        </a>
#       </li>
#       <li>
#        <a class="btn-register btn-register-show" href="javascript:void(0)">
#         Sign up
#        </a>
#       </li>
#      </ul>
#      <ul class="social-media-nav">
#       <li>
#        <a href="https://pk.linkedin.com/company/connect-mentors" target="_blank">
#         <img src="/images/linkedin-logo.svg"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www.facebook.com/connectmentors" target="_blank">
#         <img src="/images/facebook-logo.svg"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www.instagram.com/connectmentors/" target="_blank">
#         <img src="/images/instagram-logo.svg"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://twitter.com/Connectmentors" target="_blank">
#         <img src="/images/twitter.svg"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://medium.com/@Connectmentors" target="_blank">
#         <img src="/images/medium.svg"/>
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="tc-section">
#     <div class="content">
#      <a class="logo" href="/">
#       <img alt="site logo" src="https://connect-mentors.s3.eu-west-2.amazonaws.com/shared/app.png"/>
#      </a>
#      <div class="copyright-content">
#       <ul>
#        <li>
#         <a href="/legal/terms">
#          Terms and Conditions
#         </a>
#        </li>
#        <li>
#         <a href="/PrivacyPolicy">
#          Privacy Policy
#         </a>
#        </li>
#        <li>
#         © 2021 Connect Mentors All Rights Reserved.
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#    <div class="stick-sign-up-section cookie-policy-bottom-banner" style="display: block;">
#     <div class="container">
#      <span>
#       By using Connect Mentors you agree to our
#       <a href="/PrivacyPolicy">
#        Cookie Policy
#       </a>
#      </span>
#      <div class="stick-footer-buttons-container">
#       <button class="btn-account btn-register btn-cookies-agree" data-cookie=".AspNet.Consent=yes; expires=Sun, 06 Mar 2022 14:58:30 GMT; path=/; secure; samesite=lax">
#        I Agree
#       </button>
#       <button class="btn-account btn-register btn-cookies-disagree">
#        I Disagree
#       </button>
#      </div>
#      <button class="btn-close btn-cookies-disagree">
#       <img alt="Alternate Text" src="/images/btn-close.svg"/>
#      </button>
#     </div>
#    </div>
#    <div class="stick-sign-up-section register-bottom-banner" style="display:none">
#     <div class="container">
#      <span>
#       Signing up as a mentee is free and easy! Get connected today!
#      </span>
#      <div class="stick-footer-buttons-container">
#       <button class="btn-account btn-register btn-register-show">
#        Sign up for free
#       </button>
#      </div>
#      <button class="btn-close btn-close-footer">
#       <img alt="Alternate Text" src="/images/btn-close.svg"/>
#      </button>
#     </div>
#    </div>
#   </footer>
#   <div class="aerate-modal" id="sign-up">
#    <div class="modal-container">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button class="btn-close-modal btn-signup-close" onclick="utils.closeModal('sign-up');">
#        Close
#       </button>
#      </div>
#      <div class="modal-body">
#       <h2 class="title">
#        Sign up to Connect Mentors
#       </h2>
#       <div id="signup-container">
#        <button class="btn-sign-in-linked-in btn-linked-in-login">
#         <i>
#          <img alt="LinkedIn Logo" src="/images/linkedin-logo.svg"/>
#         </i>
#         <span class="btn-linked-in-label">
#          Sign in with LinkedIn
#         </span>
#        </button>
#        <span class="sign-up-alternative-title">
#         Or
#        </span>
#        <form id="register-form" novalidate="novalidate">
#         <div class="alternative-sign-up-form">
#          <div class="form-field">
#           <input autocomplete="off" id="registerFirstName" name="registerFirstName" placeholder="First Name *" required="" type="text"/>
#          </div>
#          <div class="form-field">
#           <input autocomplete="off" id="registerLastName" name="registerLastName" placeholder="Last Name *" required="" type="text"/>
#          </div>
#          <div class="form-field">
#           <input autocomplete="off" id="registerEmail" name="registerEmail" placeholder="Email *" required="" type="email"/>
#          </div>
#          <div class="form-field">
#           <input autocomplete="off" id="registerPassword" name="registerPassword" placeholder="Password *" required="" type="password"/>
#          </div>
#          <div class="form-field">
#           <input autocomplete="off" id="registerConfirmPassword" name="registerConfirmPassword" placeholder="Confirm Password *" required="" type="password"/>
#          </div>
#          <br/>
#          <div class="checkbox-container terms">
#           <label class="custom-checkbox-container" for="registertermsAgree">
#            <input id="registertermsAgree" name="registertermsAgree" required="" type="checkbox"/>
#            <p>
#             I agree to the
#             <a href="/legal/terms">
#              terms &amp; conditions
#             </a>
#            </p>
#           </label>
#          </div>
#          <div class="checkbox-container terms">
#           <label class="custom-checkbox-container" for="marketingOptIn">
#            <input id="marketingOptIn" name="marketingOptIn" type="checkbox"/>
#            <p class="">
#             Please keep me updated by sending me an email
#            </p>
#           </label>
#          </div>
#          <button class="btn-modal-action" data-loading-message="Registering..." data-message="Get Connected" id="btn-register">
#           Get Connected
#          </button>
#          <a class="lnk-sign-in" href="javascript:void(0)" onclick="utils.closeModal('sign-up'); $('.mobile-menu').fadeOut(); utils.openModal('sign-in')">
#           Already signed up with us? Log in here
#          </a>
#         </div>
#        </form>
#       </div>
#       <div id="signup-success-container" style="display:none">
#        <p class="modal-success-message">
#         Thank you! Please follow the instructions sent to your registered email address to confirm your account.
#        </p>
#        <button class="btn-modal-action" onclick="utils.closeModal('sign-up'); $('.mobile-menu').fadeOut();">
#         Close
#        </button>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="aerate-modal" id="sign-in">
#    <div class="modal-container">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button class="btn-close-modal" onclick="utils.closeModal('sign-in');">
#        Close
#       </button>
#      </div>
#      <div class="modal-body" id="login-container">
#       <h2 class="title">
#        Log in to Connect Mentors
#       </h2>
#       <button class="btn-sign-in-linked-in btn-linked-in-login">
#        <i>
#         <img alt="LinkedIn Logo" src="/images/linkedin-logo.svg"/>
#        </i>
#        <span class="btn-linked-in-label">
#         Sign in with LinkedIn
#        </span>
#       </button>
#       <span class="sign-up-alternative-title">
#        Or
#       </span>
#       <div class="alternative-sign-up-form">
#        <form id="login-form" novalidate="novalidate">
#         <input id="loginEmail" name="loginEmail" placeholder="EMAIL" required="" type="email"/>
#         <input id="loginPassword" name="loginPassword" placeholder="PASSWORD" required="" type="password"/>
#         <a class="lnk-reset-password" href="#" id="show-forgot-password">
#          Forgot your password? Click here to reset
#         </a>
#         <span id="login-error" style="color: red;display: none">
#          Invalid login details
#         </span>
#         <br/>
#         <div class="checkbox-container">
#          <label class="custom-checkbox-container">
#           <input checked="checked" id="login-remember-me" type="checkbox"/>
#           <p>
#            Remember me on this device
#           </p>
#          </label>
#         </div>
#         <button class="btn-modal-action" data-loading-message="Logging in..." id="btn-login">
#          Log in
#         </button>
#         <a class="lnk-sign-in" href="#" onclick="utils.closeModal('sign-in'); $('.mobile-menu').fadeOut(); utils.openModal('sign-up')">
#          Don't have an account? Create one here
#         </a>
#        </form>
#       </div>
#      </div>
#      <div class="modal-body" id="forgot-password-container" style="display: none">
#       <h2 class="title">
#        Forgot Password
#       </h2>
#       <div class="alternative-sign-up-form">
#        <form id="forgot-password-form" novalidate="novalidate">
#         <input id="forgotPasswordEmail" name="forgotPasswordEmail" placeholder="EMAIL" required="" type="email"/>
#         <a class="lnk-reset-password" href="#" id="show-login">
#          Remembered your password? Click here to login
#         </a>
#         <button class="btn-modal-action" data-loading-message="Resetting..." data-message="Reset" id="btn-reset-password">
#          Reset
#         </button>
#         <a class="lnk-sign-in" href="#" onclick="utils.closeModal('sign-in'); $('.mobile-menu').fadeOut(); utils.openModal('sign-up')">
#          Don't have an account? Create one here
#         </a>
#        </form>
#        <div id="forgot-password-success-container" style="display: none">
#         <p class="modal-success-message">
#          If we found your account, reset instructions have been sent to your registered email address
#         </p>
#         <button class="btn-modal-action" onclick="utils.closeModal('sign-in'); $('.mobile-menu').fadeOut();">
#          Close
#         </button>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="aerate-modal" id="account-settings">
#    <div class="modal-container">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button class="btn-close-modal" onclick="utils.closeModal('account-settings');">
#        Close
#       </button>
#      </div>
#      <div class="modal-body">
#       <h2 class="title">
#        Change Password
#       </h2>
#       <form class="alternative-sign-up-form" id="change-password-modal" novalidate="novalidate">
#        <div class="controls-container with-bold-label">
#         <label>
#          Current password
#         </label>
#         <input id="change-password-current-password" name="changePasswordCurrentPassword" placeholder="Enter your current password" required="" type="password"/>
#        </div>
#        <div class="controls-container with-bold-label">
#         <label>
#          New password
#         </label>
#         <input id="change-password-new-password" name="changePasswordNewPassword" placeholder="Enter yout new password" required="" type="password"/>
#        </div>
#        <div class="controls-container with-bold-label">
#         <label>
#          Confirm new password
#         </label>
#         <input id="change-password-new-password-confirm" name="changePasswordNewPasswordConfirm" placeholder="Enter your new password again" required="" type="password"/>
#        </div>
#        <button class="btn-modal-action" data-loading-message="Saving..." id="change-password-save">
#         Save
#        </button>
#       </form>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="aerate-modal" id="registration-steps">
#    <div class="modal-container">
#     <div class="modal-content">
#      <div class="modal-header">
#       <h2 class="title registration-steps-current-step" id="registration-steps-current-step">
#        Step 1 of 4
#       </h2>
#       <button class="btn-close-modal" onclick="utils.closeModal('registration-steps');">
#        Close
#       </button>
#       <button class="btn-back-step" id="registration-steps-back" style="display:none">
#        Go Back
#       </button>
#      </div>
#      <div class="modal-body registration-wizard-step" id="registration-step-1" style="display:none">
#       <h2 class="title">
#        Welcome
#        <span class="registration-user-forename">
#        </span>
#       </h2>
#       <h3 class="sub-title">
#        Please tell us more about yourself
#       </h3>
#       <div class="single-image-upload-container">
#        <button class="btn-single-image-upload" onclick="$('#registration-profile-image-file').click()">
#         <img alt="User profile Image" class="registration-profile-image" src="/images/upload-button.png"/>
#        </button>
#        <input class="registration-step-1-field" data-name="profileImage" id="registration-profile-image-file" style="display: none" type="file"/>
#       </div>
#       <form class="alternative-sign-up-form" id="registration-form-step-1" novalidate="novalidate">
#        <div class="controls-container col-2">
#         <div class="control-group">
#          <select class="registration-step-1-field" data-name="ageGroupId" id="registrationAgeGroup" name="registrationAgeGroup">
#           <option value="">
#            AGE GROUP *
#           </option>
#          </select>
#         </div>
#         <div class="control-group">
#          <select class="registration-step-1-field" data-name="genderId" id="registrationGender" name="registrationGender">
#           <option value="">
#            GENDER *
#           </option>
#          </select>
#         </div>
#        </div>
#        <select class="registration-step-1-field" data-name="countryId" id="registrationCountry" name="registrationCountry">
#         <option value="">
#          COUNTRY *
#         </option>
#        </select>
#        <select aria-hidden="true" class="registration-step-1-field select2-hidden-accessible" data-name="cityId" data-select2-id="registrationCity" id="registrationCity" name="registrationCity" tabindex="-1">
#         <option data-select2-id="1" value="">
#          CITY *
#         </option>
#        </select>
#        <span class="select2 select2-container select2-container--default" data-select2-id="2" dir="ltr" style="width: auto;">
#         <span class="selection">
#          <span aria-expanded="false" aria-haspopup="true" aria-labelledby="select2-registrationCity-container" class="select2-selection select2-selection--single" role="combobox" tabindex="0">
#           <span aria-readonly="true" class="select2-selection__rendered" id="select2-registrationCity-container" role="textbox">
#            <span class="select2-selection__placeholder">
#             Select a city
#            </span>
#           </span>
#           <span class="select2-selection__arrow" role="presentation">
#            <b role="presentation">
#            </b>
#           </span>
#          </span>
#         </span>
#         <span aria-hidden="true" class="dropdown-wrapper">
#         </span>
#        </span>
#        <div class="controls-container">
#         <label>
#          How did you hear about us?
#         </label>
#         <select class="registration-step-1-field" data-name="hearAboutId" id="registrationHearAbout" name="registrationHearAbout">
#          <option value="">
#           SELECT AN OPTION *
#          </option>
#         </select>
#        </div>
#        <button class="btn-modal-action registration-next-step" data-fields="registration-step-1-field" data-form="registration-form-step-1" data-next-step="2" data-saving-message="Saving...">
#         Next Step
#        </button>
#       </form>
#      </div>
#      <div class="modal-body registration-wizard-step" id="registration-step-2" style="display:none">
#       <h2 class="title">
#        OK
#        <span class="registration-user-forename">
#        </span>
#        , tell us some more
#       </h2>
#       <h3 class="sub-title">
#        This will help us to connect you with your perfect match
#       </h3>
#       <form class="alternative-sign-up-form" id="registration-form-step-2" novalidate="novalidate">
#        <div class="controls-container col-2">
#         <div class="control-group">
#          <select class="registration-step-2-field" data-name="educationId" id="registrationEducation" name="registrationEducation">
#           <option value="">
#            EDUCATION *
#           </option>
#          </select>
#         </div>
#         <div class="control-group">
#          <select class="registration-step-2-field" data-name="professionalQualificationId" id="registrationProfessionalQualification" name="registrationProfessionalQualification">
#           <option value="">
#            PROFESSIONAL QUALIFICATIONS *
#           </option>
#          </select>
#         </div>
#        </div>
#        <select class="registration-step-2-field" data-name="workExperienceId" id="registrationWorkExperience" name="registrationWorkExperience">
#         <option value="">
#          WORK EXPERIENCE *
#         </option>
#        </select>
#        <div class="skills-container">
#         <input class="registration-step-2-field" data-name="skills" id="registrationSkillIds" name="registrationSkillIds" type="hidden" value=""/>
#         <div class="skills-header">
#          <label>
#           Please choose your to three career interests
#          </label>
#          <input autocomplete="off" id="registration-search-skills" placeholder="Search interests..." type="text"/>
#         </div>
#         <div class="skills-list" id="registration-skills-list">
#         </div>
#        </div>
#        <div class="modal-error-container" id="registration-error-select-skills" style="display:none">
#         <p class="modal-error">
#          Select
#          <span id="registration-skill-count">
#           3
#          </span>
#          skills you would like to work on
#         </p>
#        </div>
#        <div class="modal-error-container" id="registration-warning-select-skills" style="display:none">
#         <p class="modal-error">
#          You have reached your full selection of interests
#         </p>
#        </div>
#        <button class="btn-modal-action registration-next-step" data-fields="registration-step-2-field" data-form="registration-form-step-2" data-next-step="3" data-saving-message="Saving...">
#         Next Step
#        </button>
#       </form>
#      </div>
#      <div class="modal-body registration-wizard-step" id="registration-step-3" style="display:none">
#       <h2 class="title">
#        Choose your Mentor!
#       </h2>
#       <h3 class="sub-title">
#        Click on a Mentor to read more about them
#       </h3>
#       <div class="mentors-list" id="registration-step-3-mentors-list">
#       </div>
#       <button class="btn-modal-action registration-show-more-mentors">
#        Show More
#       </button>
#       <div style="display:none">
#        <a class="mentor-item" id="registration-mentor-list-item">
#         <div class="mentor-image-container">
#          <img alt="" class="mentor-image" src=""/>
#         </div>
#         <div class="mentor-details-content">
#          <h3 class="mentor-location">
#          </h3>
#          <h2 class="mentor-name">
#          </h2>
#          <h4 class="mentor-position">
#          </h4>
#          <p class="mentor-skills">
#          </p>
#         </div>
#        </a>
#       </div>
#      </div>
#      <div class="modal-body registration-wizard-step" id="registration-step-4" style="display:none">
#       <h2 class="title">
#        Time to introduce yourself!
#       </h2>
#       <h3 class="sub-title">
#        What would you like to get out of being mentored?
#       </h3>
#       <div class="double-image-upload-container">
#        <button class="btn-double-image-upload">
#         <img alt="User Image" class="registration-profile-image" src="/images/no-user-image.gif"/>
#        </button>
#        <button class="btn-double-image-upload">
#         <img alt="" class="registration-selected-mentor-image" src=""/>
#        </button>
#       </div>
#       <form class="alternative-sign-up-form" id="registration-form-step-4" novalidate="novalidate">
#        <div class="controls-container">
#         <label>
#          I would like to work on my… (eg. skillset, confidence, network)
#         </label>
#         <input class="registration-step-4-field" data-name="firstExample" id="registrationFirstExample" name="registrationFirstExample" placeholder="First Example" type="text"/>
#         <input class="registration-step-4-field" data-name="secondExample" id="registrationSecondExample" name="registrationSecondExample" placeholder="Second Example" type="text"/>
#         <input class="registration-step-4-field" data-name="thirdExample" id="registrationThirdExample" name="registrationThirdExample" placeholder="Third Example" type="text"/>
#        </div>
#        <div class="controls-container">
#         <label>
#          Say hello! Add a personal message to introduce yourself to your Mentor.
#         </label>
#         <textarea class="registration-step-4-field" data-name="personalMessage" id="registrationPersonalMessage" name="registrationPersonalMessage" placeholder="Write here" rows="5"></textarea>
#        </div>
#        <div class="controls-container">
#         <label>
#          Why have you joined Connect Mentors?
#         </label>
#         <select class="connect-reason-option registration-step-4-field" data-name="whyJoined" id="registrationWhyJoined" name="registrationWhyJoined">
#         </select>
#         <input class="registration-step-4-field" data-name="whyJoinedCustom" id="registrationWhyJoinedOther" name="registrationWhyJoinedOther" placeholder="IF 'OTHER' PLEASE, SPECIFY" style="display:none;" type="text"/>
#        </div>
#        <button class="btn-modal-action" id="registrationSendMessage">
#         Send message
#        </button>
#       </form>
#      </div>
#      <div class="modal-body registration-wizard-step" id="registration-step-5" style="display:none">
#       <h2 class="title">
#        Success!
#       </h2>
#       <div class="paragraph-container">
#        <p>
#         Your message has been sent to your Mentor and you will be notified of a response via email. While you wait, why not check us out on social media?
#        </p>
#       </div>
#       <div class="social-links-content">
#        <a class="social-link" href="https://pk.linkedin.com/company/connect-mentors" target="_blank">
#         <i class="fab fa-linkedin">
#         </i>
#        </a>
#        <a class="social-link" href="https://www.facebook.com/connectmentors" target="_blank">
#         <i class="fab fa-facebook-f">
#         </i>
#        </a>
#        <a class="social-link" href="https://twitter.com/Connectmentors" target="_blank">
#         <i class="fab fa-twitter">
#         </i>
#        </a>
#        <a class="social-link" href="https://www.instagram.com/connectmentors/" target="_blank">
#         <i class="fab fa-instagram">
#         </i>
#        </a>
#        <a class="social-link" href="https://medium.com/@Connectmentors" target="_blank">
#         <i class="fab fa-medium">
#         </i>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="aerate-modal" id="confirm-modal" style="display:none">
#    <div class="modal-container">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button class="btn-close-modal" onclick="utils.closeModal('confirm-modal');">
#        Close
#       </button>
#      </div>
#      <div class="modal-body">
#       <h2 class="title modal-title confirm-modal-title">
#        Are you sure?
#       </h2>
#       <p class="confirm-modal-message">
#       </p>
#       <div class="alternative-sign-up-form">
#        <p class="modal-message">
#         Are you sure you want to do that?
#        </p>
#        <button class="btn-modal-action confirm-modal-yes">
#         Yes
#        </button>
#        <button class="btn-modal-action" onclick="utils.closeModal('confirm-modal');">
#         No
#        </button>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="aerate-modal" id="message-contacts">
#    <div class="modal-container">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button class="btn-close-modal btn-signup-close" onclick="utils.closeModal('message-contacts');">
#        Close
#       </button>
#      </div>
#      <div class="modal-body">
#       <h2 class="title">
#        Contacts
#       </h2>
#       <div class="modal-messages-panel">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="registration-mentor-profile-container">
#   </div>
#   <script src="/lib/jquery/dist/jquery.js">
#   </script>
#   <script src="/lib/jquery-validation/dist/jquery.validate.min.js">
#   </script>
#   <script src="/lib/js-cookie/js-cookie.js">
#   </script>
#   <script src="/lib/moment/moment.min.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/select2/4.0.6-rc.0/js/select2.min.js">
#   </script>
#   <script src="/js/swiper.min.js">
#   </script>
#   <script src="/lib/aspnet/signalr/dist/browser/signalr.min.js">
#   </script>
#   <script src="/js/site.min.js?v=KjgUe8UWyl3Q3IF6ODgHTtIeNP1s2d3XoGSry-TQRt4">
#   </script>
#   <div class="mobile-menu">
#    <div class="menu-content">
#     <div class="account-container">
#      <button class="btn-account btn-register btn-register-show">
#       Sign up for free
#      </button>
#      <button class="btn-account btn-login btn-login-show">
#       Log in
#      </button>
#     </div>
#     <nav class="ul-nav">
#      <ul>
#       <li>
#        <a href="/howitworks">
#         How it works
#        </a>
#       </li>
#       <li class="active">
#        <a href="/mentors">
#         Mentors
#        </a>
#       </li>
#       <li>
#        <a href="/companies">
#         Companies
#        </a>
#       </li>
#       <li>
#        <a href="/partners">
#         Partners
#        </a>
#       </li>
#       <li>
#        <a href="/skills">
#         Skills
#        </a>
#       </li>
#       <li id="lnk-about" style="">
#        <a href="/about">
#         About
#        </a>
#       </li>
#      </ul>
#     </nav>
#    </div>
#   </div>
#  </body>
# </html>

# %%
# element = soup.select_one('ul._3Xnzg_3g8J4')
element = soup.select_one('div.mentor-list-container div.mentor-head')

mentorName = element.find('div', class_='mentor-head').get_text()
print(mentorName)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-f956857f4987> in <module>
#       2 element = soup.select_one('div.mentor-list-container')
#       3
# ----> 4 mentorName = element.find('div.mentor-head h3.mentor-name').get_text()
#       5 print(mentorName)
#
# AttributeError: 'NoneType' object has no attribute 'get_text'
